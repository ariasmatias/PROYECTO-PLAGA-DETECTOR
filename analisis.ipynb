# %%
import os
import cv2
import csv

folder = "set_extraido"
imagenes = [f for f in os.listdir(folder) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]

# Archivo CSV donde se guardarán las coordenadas
csv_file = "rois.csv"

with open(csv_file, mode='w', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(["imagen", "x", "y", "w", "h"])  # cabecera

    for img_name in imagenes:
        path = os.path.join(folder, img_name)
        img = cv2.imread(path)

        # Seleccionar ROI
        roi = cv2.selectROI("Imagen", img, showCrosshair=True, fromCenter=False)
        x, y, w, h = roi
        print(f"{img_name} -> ROI seleccionada: x={x}, y={y}, w={w}, h={h}")

        # Guardar en CSV
        writer.writerow([img_name, x, y, w, h])

        # Dibujar rectángulo y mostrarlo
        if w > 0 and h > 0:
            cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 2)
            cv2.imshow("Imagen con ROI", img)
            cv2.waitKey(500)

cv2.destroyAllWindows()
print(f"✅ Todas las coordenadas se guardaron en {csv_file}")
# Out:
# 1.jpg -> ROI seleccionada: x=152, y=67, w=160, h=169
# 1069.jpg -> ROI seleccionada: x=65, y=18, w=183, h=357
# 1082.jpg -> ROI seleccionada: x=161, y=214, w=288, h=108
# 11.jpg -> ROI seleccionada: x=96, y=41, w=206, h=150
# 1118.jpg -> ROI seleccionada: x=132, y=59, w=299, h=392
# 1122.jpg -> ROI seleccionada: x=55, y=82, w=292, h=221
# 12.jpg -> ROI seleccionada: x=145, y=24, w=170, h=229
# 1267.jpg -> ROI seleccionada: x=123, y=87, w=183, h=129
# 1270.jpg -> ROI seleccionada: x=114, y=38, w=232, h=237
# 13.jpg -> ROI seleccionada: x=36, y=33, w=188, h=175
# 1303.jpg -> ROI seleccionada: x=131, y=122, w=189, h=116
# 14.jpg -> ROI seleccionada: x=208, y=99, w=139, h=158
# 1461.jpg -> ROI seleccionada: x=183, y=160, w=151, h=109
# 1518.jpg -> ROI seleccionada: x=95, y=32, w=97, h=175
# 1551.jpg -> ROI seleccionada: x=83, y=61, w=361, h=232
# 16.jpg -> ROI seleccionada: x=99, y=58, w=234, h=175
# 17.jpg -> ROI seleccionada: x=39, y=135, w=269, h=156
# 18.jpg -> ROI seleccionada: x=218, y=115, w=166, h=150
# 19.jpg -> ROI seleccionada: x=126, y=99, w=203, h=168
# 21.jpg -> ROI seleccionada: x=63, y=118, w=255, h=114
# 24.jpg -> ROI seleccionada: x=132, y=141, w=272, h=149
# 25.jpg -> ROI seleccionada: x=90, y=88, w=299, h=175
# 26.jpg -> ROI seleccionada: x=55, y=10, w=290, h=460
# 27.jpg -> ROI seleccionada: x=69, y=59, w=213, h=171
# 28.jpg -> ROI seleccionada: x=155, y=62, w=162, h=265
# 29.jpg -> ROI seleccionada: x=111, y=69, w=248, h=269
# 3.jpg -> ROI seleccionada: x=121, y=125, w=245, h=171
# 30.jpg -> ROI seleccionada: x=105, y=139, w=187, h=266
# 307.jpg -> ROI seleccionada: x=83, y=101, w=307, h=183
# 31.jpg -> ROI seleccionada: x=47, y=28, w=138, h=141
# 32.jpg -> ROI seleccionada: x=112, y=44, w=170, h=223
# 33.jpg -> ROI seleccionada: x=177, y=52, w=207, h=276
# 34.jpg -> ROI seleccionada: x=243, y=89, w=143, h=159
# 35.jpg -> ROI seleccionada: x=114, y=73, w=188, h=156
# 37.jpg -> ROI seleccionada: x=138, y=75, w=144, h=191
# 378.jpg -> ROI seleccionada: x=54, y=127, w=296, h=190
# 38.jpg -> ROI seleccionada: x=61, y=27, w=182, h=296
# 39.jpg -> ROI seleccionada: x=125, y=28, w=213, h=198
# 4.jpg -> ROI seleccionada: x=97, y=64, w=284, h=322
# 445.jpg -> ROI seleccionada: x=130, y=8, w=211, h=369
# 448.jpg -> ROI seleccionada: x=51, y=27, w=253, h=202
# 522.jpg -> ROI seleccionada: x=122, y=79, w=217, h=171
# 588.jpg -> ROI seleccionada: x=100, y=91, w=230, h=176
# 6.jpg -> ROI seleccionada: x=170, y=85, w=172, h=194
# 614.jpg -> ROI seleccionada: x=86, y=17, w=366, h=273
# 772.jpg -> ROI seleccionada: x=136, y=128, w=269, h=180
# 78.jpg -> ROI seleccionada: x=72, y=141, w=230, h=134
# 8.jpg -> ROI seleccionada: x=118, y=83, w=181, h=162
# 9.jpg -> ROI seleccionada: x=150, y=105, w=110, h=109
# 941.jpg -> ROI seleccionada: x=217, y=173, w=145, h=130
# ✅ Todas las coordenadas se guardaron en rois.csv
